# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthi760/base/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'#API Url
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fb2b5153-c5e0-4785-88dc-acbbc1db18ec',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:11:49.470Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8396, 'name': 'i9c38hd8rw', 'symbol': 'c1sf317u4u', 'slug': '6bczc0fwr4o', 'cmc_rank': 2469, 'num_market_pairs': 2346, 'circulating_supply': 1443, 'total_supply': 3345, 'max_supply': 5878, 'infinite_supply': None, 'last_updated': '2024-02-20T06:11:49.470Z', 'date_added': '2024-02-20T06:11:49.470Z', 'tags': ['l9udpzlr4gm', 'beot6fiugg9', 'uwa2vhix6gr', 'wcdg31xdd', '8mp3k29y3cr', 'vrha3od0wwl', 'wq58dam725', '1c8tis7vmys', '5q2szz5mh7a', '97qu2yo58gt'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.2035706477150121, 'volume_24h': 5285, 'volume_change_24h': 0.8265634033857485, 'percent_change_1h': 0.27682984715883197, 'percent_change_24h': 0.7705532685018492, 'percent_change_7d': 0.15554292700335415, 'market_cap': 0.37066218091164993, 'market_cap_dominan
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  8396   i9c38hd8rw   c1sf317u4u  6bczc0fwr4o      2469              2346
# 1  4755   t7ju4kzzew  3gy76gim5j4  4vhsx0teb0s      3084              6406
# 2   927   piki6yd0tz  et83zmj3pgd  z5otxa3h62j      1169              2623
# 3  8020  ihg0hw5rowh  a6111f2f9ac  w4i2btpavo9       648              2867
# 4  5218   l1bumn8n7v   uijmqciofg  5ghoatk91zj      4994               749
# 5   988  xn5j0xyxzmb  es0r70bhvjj  uhabt4uluui      8490              4318
# 6  3731  9zbavjhc7wm  t1khi8ou57i  d425e13h0qs      6291              1923
# 7  9296   4waf07wn15  8xuxgl2lcl5  3pgphs0p852      8740              5370
# 8  8094  8tpqbfi3zww  wgoxj1t6f6g  gjkgw88zfce        37              7117
# 9  4146  xltdhluw6xp  bezgik5ak8g  1zkccioeqp6      3739              6087
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                1443          3345        5878            None  ...
# ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'#API Url
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'fb2b5153-c5e0-4785-88dc-acbbc1db18ec',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:12:58.972Z', 'error_code': 0, 'error_message': None, 'elapsed': 20, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 0       1        Bitcoin    BTC        bitcoin             10821
# 1    1027       Ethereum    ETH       ethereum              8428
# 2     825    Tether USDt   USDT         tether             74897
# 3    1839            BNB    BNB            bnb              2070
# 4    5426         Solana    SOL         solana               626
# ..    ...            ...    ...            ...               ...
# 95   1042        Siacoin     SC        siacoin                95
# 96   7548          WEMIX  WEMIX          wemix                52
# 97   1659         Gnosis    GNO     gnosis-gno               169
# 98  13631  Manta Network  MANTA  manta-network                84
# 99  17799         Axelar    AXL         axelar                82
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ...

# %%
#accessing an API which don't have any API
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/77.jpg","link":"https:\/\/randomfox.ca\/?i=77"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/77.jpg

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.weatherapi.com/v1/current.json?key=c86177dae4104c4593f70959242002&q=London'  #actual url
parameters = {
  'start':'1',
  'limit':'2767',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd15f875f4c6f4865b8c70158242002',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1708417459, 'localtime': '2024-02-20 8:24'}, 'current': {'last_updated_epoch': 1708416900, 'last_updated': '2024-02-20 08:15', 'temp_c': 7.0, 'temp_f': 44.6, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 8.1, 'wind_kph': 13.0, 'wind_degree': 220, 'wind_dir': 'SW', 'pressure_mb': 1028.0, 'pressure_in': 30.36, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 93, 'cloud': 75, 'feelslike_c': 4.3, 'feelslike_f': 39.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 2.0, 'gust_mph': 13.9, 'gust_kph': 22.4}}

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data)

# %%
norm
# Out:
#   location.name                 location.region location.country  \
# 0        London  City of London, Greater London   United Kingdom
#
#    location.lat  location.lon location.tz_id  location.localtime_epoch  \
# 0         51.52         -0.11  Europe/London                1708413676
#
#   location.localtime  current.last_updated_epoch current.last_updated  ...  \
# 0    2024-02-20 7:21                  1708413300     2024-02-20 07:15  ...
#
#    current.precip_in  current.humidity  current.cloud current.feelslike_c  \
# 0                0.0                93             75                 3.2
#
#   current.feelslike_f  current.vis_km  current.vis_miles  current.uv  \
# 0                37.8            10.0                6.0         1.0
#
#    current.gust_mph current.gust_kph
# 0              13.4             21.6
#
# [1 rows x 33 columns]
